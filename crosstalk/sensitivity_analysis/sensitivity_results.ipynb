# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import Normalize
import os
import math
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

# %%
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams.update({'font.size': 20})

# %%
df = pd.read_csv("params_AS/cooperativity/EMT_MR_comp_1_1000_res.txt")

# %%
for fileN in os.listdir('params_AS/cooperativity/'):
    if "EMT_MR" in fileN and "res.txt" in fileN:
        label=fileN.split("_")[3]
        plt.plot(df['A'],df['h'],'*',label=label)
    plt.legend()

# %%
for fileN in os.listdir('params_AS/thresholds/'):
    if "EMT_MR" in fileN and "res.txt" in fileN:
        label=fileN.split("_")[3]
        plt.plot(df['A'],df['h'],'*',label=label)
    plt.legend()
