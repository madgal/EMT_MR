# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import Normalize
import os
import math
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec
import copy

# %%
from aux_func_States import *
from functions_for_plotting import *

# %%
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams.update({'font.size': 20})

# %%
dirN='data/crosstalk_AZ_AS.txt'
title = '$\lambda_{AS}$,$\lambda_{AZ}$,'
fsave='figures/crosstalk_AZ_AS'
plotCoupledPhenotypes_regulatory(dirN,title,fsave)
# Out:
# /home/madeline/anaconda2/lib/python2.7/site-packages/numpy/core/fromnumeric.py:51: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# ## AMPK-| Snail, Hif1-> SNail, Input

# %%
dirN='data/crosstalk_AS_HS_input.txt'
title = '$input$,$\lambda_{AS}$,$\lambda_{HS}$,'
fsave='figures/crosstalk_AS_HS_input'
plotCoupledPhenotypes_regulatory(dirN,title,fsave,xregList=['INPUT'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7702b045f638> in <module>()
#       3 fsave='figures/crosstalk_AS_HS_input'
#       4 plotCoupledPhenotypes_regulatory(dirN,title,fsave,xregList=['INPUT'])
# ----> 5 ax.get_xticks()
#
# NameError: name 'ax' is not defined

# %% [markdown]
# ## Hif1-| u200 and u34 -> nox/mtROS

# %%
dirN='data/crosstalk_iHu_u3m_u3n.txt'
title = '$\lambda_{u3n}$,$\lambda_{u3m}$,$\lambda_{Hu}$,'
fsave='figures/crosstalk_iHu_u3m_u3n'
plotCoupledPhenotypes_regulatory(dirN,title,fsave)

# %% [markdown]
# ## Hif1-> Snail and u34 -> nox/mtROS

# %%
dirN='data/crosstalk_u3n_u3m_HS.txt'
title = '$\lambda_{u3n}$,$\lambda_{u3m}$,$\lambda_{HS}$,'
fsave='figures/crosstalk_HS_u3m_u3n'
plotCoupledPhenotypes_regulatory(dirN,title,fsave)

# %% [markdown]
# ## Hif1-| u200 and u34 -> mtROS and input

# %%
dirN='data/crosstalk_u3m_iHu_input.txt'
title = '$input$,$\lambda_{u3m}$,$\lambda_{Hu}$,'
fsave='figures/crosstalk_iHu_u3m_input'
plotCoupledPhenotypes_regulatory(dirN,title,fsave)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-69533e278a90> in <module>()
#       2 title = '$input$,$\lambda_{u3m}$,$\lambda_{Hu}$,'
#       3 fsave='figures/crosstalk_iHu_u3m_input'
# ----> 4 plotCoupledPhenotypes_regulatory(dirN,title,fsave)
#
# /home/madeline/Research/EMT_MR/crosstalk/analysis/functions_for_plotting.py in plotCoupledPhenotypes_regulatory(fileN, title, fsave, xlog, ylog, xlim, ylim, checkRanges, xregList)
#     834             tickList[key],tickLabels[key] = {0:[0]},[0]
#     835     ####now rearrange to get xvals,yvals,labels, and hybridV
# --> 836     xval,yval,label,hybridV=getPlotData_regulatory(df,opp_label)
#     837
#     838     compHybrid=getCompHybridVal(compI=False)
#
# /home/madeline/Research/EMT_MR/crosstalk/analysis/aux_func_States.pyc in getPlotData_regulatory(df, opp_label)
#     868                     indx=tmpinds
# ...

# %% [markdown]
# ## AMPK-| Snail, Hif1-> SNail, AMPK-> u200

# %%
dirN='data/crosstalk_AS_HS_Au.txt'
title = '$\lambda_{AS}$,$\lambda_{HS}$,$\lambda_{Au}$,'
fsave='figures/crosstalk_AS_HS_Au'
plotCoupledPhenotypes_regulatory(dirN,title,fsave,xregList=['HS'])

# %% [markdown]
# ## AMPK-| Snail, Hif1-> SNail, u34-> mtROS

# %%
dirN='data/crosstalk_AS_HS_u3m.txt'
title = '$\lambda_{AS}$,$\lambda_{u3m}$,$\lambda_{HS}$,'
fsave='figures/crosstalk_AS_HS_u3m'
plotCoupledPhenotypes_regulatory(dirN,title,fsave)

# %% [markdown]
# ## AMPK-> u200, Hif1-> SNail, u34-> mtROS

# %%
dirN='data/crosstalk_Au_HS_u3m.txt'
title = '$\lambda_{Au}$,$\lambda_{u3m}$,$\lambda_{HS}$,'
fsave='figures/crosstalk_Au_HS_u3m'
plotCoupledPhenotypes_regulatory(dirN,title,fsave)

# %%
import matplotlib.patches as mpatches
import matplotlib.lines as mlines



xv = np.arange(10,1000,10)
yv = xv

fig,ax=plt.subplots()

ax.plot(xv,yv,'*')
ax.set_ylim(np.min(yv),np.max(yv))

ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_xlim(np.min(xv),np.max(xv))
ax.set_xticks([0,500,1000])

ax2 = plt.axes([0,0,1,1],facecolor=(1,1,1,0))
ax2.axis('off')
ax2.plot([np.min(xv),np.max(xv)],[-10,10])
line = mlines.Line2D([0,10,10],[10,10,10], lw=5)
ax2.add_line(line)
ax2.plot([0,10],[0,100],'--',alpha=0)
ax2.text(0,0,"X")
# Out:
# Text(0,0,'X')
