# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import Normalize
import os
import math
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

# %%
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams.update({'font.size': 20})

# %% [markdown]
# ## u34 -> mtROS and Hif1-| u200

# %%
original = pd.read_csv("../coupledWReg_Ccode/crosstalk_comparison/EMT_MR_comp_0_1000_res.txt")

# %%
problematic = pd.read_csv("../coupledWReg_Ccode/crosstalk_u3m_iHu_input/EMT_MR_comp_Hu_0_0_u3m_0_300_input_20000_1000_res.txt")

# %%
plt.plot(original['u'],original['h'],'*')

# %%
plt.plot(problematic['u'],problematic['h'],'*')

# %%
tmpOG = []
for i in range(len(original)):
    tmpOG+=[original.values[i]]
    
reduced = np.unique(np.round(tmpOG,0),axis=0)

# %%
##original.columns = u,mz,Z,ms,u3,S,A,Rmt,Rnox,h,mh
reduced = np.unique(np.round(tmpOG,0),axis=0)
for i in range(len(reduced)):
    plt.plot(reduced[i,0],reduced[i,10],'o',markersize=10,label=i)
plt.legend()
plt.xlim(0,30000)
# Out:
# (0, 30000)

# %%
for i in range(len(problematic)):
    for j in range(len(reduced)):
        distances = np.sum((problematic.values[i]-reduced)**2,axis=1)
        location= np.argwhere(np.min(distances)==distances)[:,0][0]
        print location,np.min(distances)
# Out:
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# 3 11760858985.451382
# ...

# %%
len(reduced)
# Out:
# 9

# %%
reduced
# Out:
# array([[1.26500e+03, 9.90000e+02, 7.42310e+05, 4.51000e+02, 8.17800e+03,
#         2.38330e+05, 6.90000e+01, 8.00000e+00, 3.10000e+01, 4.80000e+02,
#         5.60000e+02],
#        [1.26500e+03, 9.90000e+02, 7.42310e+05, 4.51000e+02, 8.17800e+03,
#         2.38330e+05, 3.28000e+02, 1.38000e+02, 9.00000e+00, 2.92000e+02,
#         3.41000e+02],
#        [1.26500e+03, 9.90000e+02, 7.42310e+05, 4.51000e+02, 8.17800e+03,
#         2.38330e+05, 4.36000e+02, 1.29000e+02, 2.00000e+00, 2.70000e+01,
#         3.10000e+01],
#        [1.23890e+04, 3.02000e+02, 4.55160e+04, 4.58000e+02, 1.69090e+04,
#         1.96878e+05, 6.90000e+01, 8.00000e+00, 3.10000e+01, 4.80000e+02,
#         5.60000e+02],
#        [1.23890e+04, 3.02000e+02, 4.55160e+04, 4.58000e+02, 1.69090e+04,
#         1.96878e+05, 3.28000e+02, 1.38000e+02, 9.00000e+00, 2.92000e+02,
#         3.41000e+02],
#        [1.23890e+04, 3.02000e+02, 4.55160e+04, 4.58000e+02, 1.69090e+04,
# ...

# %%
from aux_func_States import *
from functions_for_plotting import *

# %%
filen = '../coupledWReg_Ccode/crosstalk_comparison/EMT_MR_comp_0_1000_res.txt'
plotValuesEMTvMR_simple(filen,save=False)

# %%
##columns = u,mz,Z,ms,u3,S,A,Rmt,Rnox,h,mh

filen = '../coupledWReg_Ccode/crosstalk_u3m_iHu_input/EMT_MR_comp_Hu_0_0_u3m_0_300_input_20000_1000_res.txt'
plotValuesEMTvMR_simple(filen,save=False)

# %%
prob_Z=(problematic-np.mean(original,axis=0))/ np.std(original,axis=0)
og_Z=(original-np.mean(original,axis=0))/ np.std(original,axis=0)

print np.unique(original,axis=0)
print np.unique(problematic)
# Out:
# [[1.26501455e+03 9.90401024e+02 7.42309633e+05 4.51154065e+02
#   8.17793894e+03 2.38329655e+05 6.87155050e+01 8.37237700e+00
#   3.05074730e+01 4.79867662e+02 5.59845606e+02]
#  [1.26501455e+03 9.90401024e+02 7.42309633e+05 4.51154065e+02
#   8.17793894e+03 2.38329655e+05 3.27638356e+02 1.38265605e+02
#   8.94903900e+00 2.92174480e+02 3.40870227e+02]
#  [1.26501455e+03 9.90401024e+02 7.42309633e+05 4.51154065e+02
#   8.17793894e+03 2.38329655e+05 4.36489801e+02 1.28975137e+02
#   1.64608300e+00 2.66640780e+01 3.11080910e+01]
#  [1.23892176e+04 3.01843678e+02 4.55163019e+04 4.58464267e+02
#   1.69086177e+04 1.96878363e+05 6.87155050e+01 8.37237700e+00
#   3.05074730e+01 4.79867662e+02 5.59845606e+02]
#  [1.23892176e+04 3.01843678e+02 4.55163019e+04 4.58464267e+02
#   1.69086177e+04 1.96878363e+05 3.27638356e+02 1.38265605e+02
#   8.94903900e+00 2.92174480e+02 3.40870227e+02]
#  [1.23892176e+04 3.01843678e+02 4.55163019e+04 4.58464267e+02
# ...

# %%
tmpOGZ = []
for i in range(len(og_Z)):
    tmpOGZ+=[og_Z.values[i]]
    
reducedZ = np.unique(tmpOGZ,axis=0)
print len(reducedZ)
#print og_Z.columns,original.values[0],'\n'
for k in range(len(reducedZ)):
    #print reducedZ[k]*np.std(original.values,axis=0)+np.mean(original.values,axis=0)
    plt.plot(reducedZ[k][0],reducedZ[k][9],'o',markersize=20)
plt.plot(prob_Z['u'],prob_Z['h'],'*')    
plt.plot(reducedZ[4][0],reducedZ[4][9],'x',markersize=20)
# Out:
# 9

# %%
col=['b','r','pink','g','brown','yellow','orange','purple','gray']
for i in [0,1,2,4,5,6,7,8]:#range(len(reducedZ)):
    for j in range(len(reducedZ[i])):
        plt.plot(j,reducedZ[i][j],color=col[i],marker='o',markersize=(20-i*2))
        plt.plot(j,prob_Z.values[0][j],color='k',marker='o',markersize=(10))

# %%
print original.columns
print problematic.columns
print prob_Z.values[0]
mm = np.mean(original['ms'])
ss = np.std(original['ms'])
print mm,ss
print (problematic['ms'][0]-mm)/ss
print np.unique(original['ms'])
# Out:
# Index([u'u', u'mz', u'Z', u'ms', u'u3', u'S', u'A', u'Rmt', u'Rnox', u'h',
#        u'mh'],
#       dtype='object')
# Index([u'u', u'mz', u'Z', u'ms', u'u3', u'S', u'A', u'Rmt', u'Rnox', u'h',
#        u'mh'],
#       dtype='object')
# [ -0.69340785  -0.81554377  -0.53560641 -65.89420959   1.57640164
#   -5.99282351   0.50901655   3.36437919   0.23192075   1.3764307
#    1.3764307 ]
# 456.264889372 3.35379487419
# -65.89420959304846
# [451.154065 458.464267 458.511561]

# %%
for i in [1]:#range(len(prob_Z)):
    distances=0
    for j in [0,1,2,4,5,6,7,8,9,10]:
        print ((prob_Z.values[i][j]-reducedZ[:,j])**2)
        distances += ((prob_Z.values[i][j]-reducedZ[:,j])**2)
    #distances = np.sum((prob_Z.values[i]-reducedZ)**2,axis=1)
    print distances
    location= np.argwhere(np.min(distances)==distances)[:,0][0]
    print location,np.min(distances)
# Out:
# [0.64841638 0.64841638 0.64841638 1.69154082 1.69154082 1.69154082
#  6.60840216 6.60840216 6.60840216]
# [5.43245922 5.43245922 5.43245922 0.03440935 0.03440935 0.03440935
#  0.31485144 0.31485144 0.31485144]
# [4.24057521 4.24057521 4.24057521 0.01364082 0.01364082 0.01364082
#  0.0577435  0.0577435  0.0577435 ]
# [9.61180268 9.61180268 9.61180268 0.84792265 0.84792265 0.84792265
#  0.80942726 0.80942726 0.80942726]
# [56.50102647 56.50102647 56.50102647 28.48394932 28.48394932 28.48394932
#  28.33366997 28.33366997 28.33366997]
# [2.66239532 0.03320173 0.89260579 2.66239532 0.03320173 0.89260579
#  2.66239532 0.03320173 0.89260579]
# [20.40275037  6.09696497  6.84170555 20.40275037  6.09696497  6.84170555
#  20.40275037  6.09696497  6.84170555]
# [0.8113131  0.91630544 2.51738883 0.8113131  0.91630544 2.51738883
#  0.8113131  0.91630544 2.51738883]
# [ 0.17589606  2.98027553 12.78172058  0.17589606  2.98027553 12.78172058
#   0.17589606  2.98027553 12.78172058]
# ...
