# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import Normalize
import os
import math
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

# %%
from aux_func_States import *

from functions_for_plotting import *

# %%
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams.update({'font.size': 20})

# %%
fileN = 'data/PSF_crosstalk_AS.txt'
xlabel='AS'
title='AS'
fsave= 'figures/'+fileN.split("/")[-1].split('.')[0]
plotCoupledPhenotypes_singleLink(fileN,xlabel,title,fsave)
plotICSvlambda_singleLink(fileN,xlabel,title,fsave)

# %%
fileN = 'data/PSF_crosstalk_Au.txt'
xlabel='Au'
title='Au'
fsave= 'figures/'+fileN.split("/")[-1].split('.')[0]
plotCoupledPhenotypes_singleLink(fileN,xlabel,title,fsave)
plotICSvlambda_singleLink(fileN,xlabel,title,fsave)

fileN = 'data/PSF_crosstalk_HS.txt'
xlabel='HS'
title='HS'
fsave= 'figures/'+fileN.split("/")[-1].split('.')[0]
plotCoupledPhenotypes_singleLink(fileN,xlabel,title,fsave)
plotICSvlambda_singleLink(fileN,xlabel,title,fsave)

fileN = 'data/PSF_crosstalk_Hu.txt'
xlabel='Hu'
title='Hu'
fsave= 'figures/'+fileN.split("/")[-1].split('.')[0]
plotCoupledPhenotypes_singleLink(fileN,xlabel,title,fsave)
plotICSvlambda_singleLink(fileN,xlabel,title,fsave)

fileN = 'data/PSF_crosstalk_u3m.txt'
xlabel='u3m'
title='u3m'
fsave= 'figures/'+fileN.split("/")[-1].split('.')[0]
plotCoupledPhenotypes_singleLink(fileN,xlabel,title,fsave)
plotICSvlambda_singleLink(fileN,xlabel,title,fsave)

fileN = 'data/PSF_crosstalk_u3n.txt'
xlabel='u3n'
title='u3n'
fsave= 'figures/'+fileN.split("/")[-1].split('.')[0]
plotCoupledPhenotypes_singleLink(fileN,xlabel,title,fsave)
plotICSvlambda_singleLink(fileN,xlabel,title,fsave)

fileN = 'data/PSF_crosstalk_uh.txt'
xlabel='uh'
title='uh'
fsave= 'figures/'+fileN.split("/")[-1].split('.')[0]
plotCoupledPhenotypes_singleLink(fileN,xlabel,title,fsave)
plotICSvlambda_singleLink(fileN,xlabel,title,fsave)

# %%
fileN = 'data/PSF_crosstalk_Au_HS.txt'
xlabel='Au'
ylabel='HS'
title='Au, HS'
fsave= 'figures/'+fileN.split("/")[-1].split('.')[0]
plotCoupledPhenotypes_doubleLink(fileN,xlabel,ylabel,title,fsave)

# %%
fileN = 'data/PSF_crosstalk_AS_Hu.txt'
xlabel='AS'
ylabel='Hu'
title='AS, Hu'
fsave= 'figures/'+fileN.split("/")[-1].split('.')[0]
plotCoupledPhenotypes_doubleLink(fileN,xlabel,ylabel,title,fsave)
