# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import Normalize
import os
import math
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

# %%
from aux_func_States import *

from functions_for_plotting import *

# %%
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams.update({'font.size': 20})

# %% [markdown]
# ### Input only

# %%
fileN = 'data/crosstalk_input.txt'
xlabel='input'
title='input'
fsave='figures/crosstalk_input'
plotCoupledPhenotypes_singleLink(fileN,xlabel,title,fsave)


plotICSvlambda_singleLink(fileN,xlabel,title,fsave)
# Out:
# Values for  0 = [[55000.0, -0.5], [65000.0, 0.5]]
# 55000.0 65000.0 -0.5 0.5
# Values for  1 = [[45000.0, -0.5], [55000.0, 0.5]]
# 45000.0 55000.0 -0.5 0.5

# %% [markdown]
# # Double links

# %% [markdown]
# ## Ampk -| Snail

# %%
dirN='data/crosstalk_AS_input.txt'
ylabel='AS'#'$\lambda_{AMPK-|Snail}$'
xlabel='input'#'Input to Snail'

title='Input and $\lambda_{AMPK-|Snail}$'
fsave='figures/crosstalk_AS_input'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave)
#plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave,onlyShowHybrid='EM')

#for i in range(1,10):
#    fsave='figures/crosstalk_input_AS_0_'+str(i)
#    las = i*0.1
#    plotICSvlambda_Input(dirN,xlabel,title,fsave,links=1,lAS=las)
# Out:
# Values for  0 = [[65000.0, 0.6499999999999999], [75000.0, 0.75], [75000.0, 0.55], [85000.0, 0.6499999999999999]]
# 65000.0 85000.0 0.55 0.75
# Locs  [[6.5e+04 6.5e-01]
#  [7.5e+04 7.5e-01]
#  [7.5e+04 5.5e-01]
#  [8.5e+04 6.5e-01]]
# Values for  1 = [[85000.0, 0.55], [95000.0, 0.6499999999999999], [95000.0, 0.45], [100000.0, 0.55]]
# 85000.0 100000.0 0.45 0.6499999999999999
# Locs  [[8.5e+04 5.5e-01]
#  [9.5e+04 6.5e-01]
#  [9.5e+04 4.5e-01]
#  [1.0e+05 5.5e-01]]
# Values for  2 = [[65000.0, 0.55], [75000.0, 0.6499999999999999], [75000.0, 0.45], [85000.0, 0.55], [85000.0, 0.45], [95000.0, 0.55], [95000.0, 0.35], [100000.0, 0.45]]
# 65000.0 100000.0 0.35 0.6499999999999999
# Locs  [[6.5e+04 5.5e-01]
#  [7.5e+04 6.5e-01]
#  [7.5e+04 4.5e-01]
#  [8.5e+04 5.5e-01]
#  [8.5e+04 4.5e-01]
#  [9.5e+04 5.5e-01]
#  [9.5e+04 3.5e-01]
#  [1.0e+05 4.5e-01]]
# Values for  3 = [[65000.0, 0.75], [75000.0, 0.8500000000000001], [75000.0, 0.6499999999999999], [85000.0, 0.75], [95000.0, 0.55], [100000.0, 0.6499999999999999]]
# 65000.0 100000.0 0.55 0.8500000000000001
# Locs  [[6.5e+04 7.5e-01]
#  [7.5e+04 8.5e-01]
#  [7.5e+04 6.5e-01]
#  [8.5e+04 7.5e-01]
#  [9.5e+04 5.5e-01]
#  [1.0e+05 6.5e-01]]
# Values for  4 = [[55000.0, 0.75], [65000.0, 0.8500000000000001]]
# 55000.0 65000.0 0.75 0.8500000000000001
# Values for  5 = [[55000.0, 0.8500000000000001], [65000.0, 0.9]]
# 55000.0 65000.0 0.8500000000000001 0.9
# Values for  6 = [[55000.0, 0.05], [65000.0, 0.1]]
# 55000.0 65000.0 0.05 0.1
# Values for  7 = [[45000.0, 0.1], [55000.0, 0.15000000000000002]]
# 45000.0 55000.0 0.1 0.15000000000000002

# %% [markdown]
# ## Hif1-> Snail

# %%
dirN='data/crosstalk_HS_input.txt'
ylabel='HS'#'$\lambda_{Hif1->Snail}$'
xlabel='input'#'Input to Snail'

title='Input and $\lambda_{Hif1->Snail}$'
fsave='figures/crosstalk_HS_input'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave,ylim=[1,14])
#plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave,onlyShowHybrid='EM',ylim=[1,14])

#for i in range(1,15):
#    fsave='figures/crosstalk_input_HS_'+str(i)
#    las = i*1.
#    plotICSvlambda_Input(dirN,xlabel,title,fsave,links=1,lAS=las)
# Out:
# Values for  0 = [[0.0, 7.5], [5000.0, 8.5], [5000.0, 5.5], [15000.0, 6.5]]
# 0.0 15000.0 5.5 8.5
# Locs  [[0.0e+00 7.5e+00]
#  [5.0e+03 8.5e+00]
#  [5.0e+03 5.5e+00]
#  [1.5e+04 6.5e+00]]
# Values for  1 = [[25000.0, 1.5], [35000.0, 2.5]]
# 25000.0 35000.0 1.5 2.5
# Values for  2 = [[55000.0, 0.5], [65000.0, 1.5]]
# 55000.0 65000.0 0.5 1.5
# Values for  3 = [[45000.0, 0.5], [55000.0, 1.5]]
# 45000.0 55000.0 0.5 1.5

# %% [markdown]
# ## Hif1-| u200

# %%
dirN='data/crosstalk_iHu_input.txt'
ylabel='Hu'#'$\lambda_{Hif1-|\mu_{200}}$'
xlabel='input'#'Input to Snail'

title='Input and $\lambda_{Hif1-|\mu_{200}}$'
fsave='figures/crosstalk_iHu_input'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave)
#plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave,onlyShowHybrid='EM')

#for i in range(1,10):
#    fsave='figures/crosstalk_input_iHu_0_'+str(i)
#    las = i*0.1
#    plotICSvlambda_Input(dirN,xlabel,title,fsave,links=1,lAS=las)
# Out:
# Values for  0 = [[25000.0, 0.0], [35000.0, 0.05], [25000.0, 0.1], [35000.0, 0.15000000000000002]]
# 25000.0 35000.0 0.0 0.15000000000000002
# Values for  1 = [[15000.0, 0.0], [25000.0, 0.05]]
# 15000.0 25000.0 0.0 0.05
# Values for  2 = [[45000.0, 0.75], [55000.0, 0.8500000000000001]]
# 45000.0 55000.0 0.75 0.8500000000000001
# Values for  3 = [[25000.0, 0.15000000000000002], [35000.0, 0.25]]
# 25000.0 35000.0 0.15000000000000002 0.25
# Values for  4 = [[35000.0, 0.45], [45000.0, 0.55]]
# 35000.0 45000.0 0.45 0.55
# Values for  5 = [[35000.0, 0.35], [45000.0, 0.45]]
# 35000.0 45000.0 0.35 0.45
# Values for  6 = [[45000.0, 0.6499999999999999], [55000.0, 0.75]]
# 45000.0 55000.0 0.6499999999999999 0.75
# Values for  7 = [[55000.0, 0.1], [65000.0, 0.15000000000000002]]
# 55000.0 65000.0 0.1 0.15000000000000002
# Values for  8 = [[35000.0, 0.55], [45000.0, 0.6499999999999999]]
# 35000.0 45000.0 0.55 0.6499999999999999
# Values for  9 = [[45000.0, 0.1], [55000.0, 0.15000000000000002], [45000.0, 0.8500000000000001], [55000.0, 0.9]]
# 45000.0 55000.0 0.1 0.9

# %% [markdown]
# ## u34 -> mtROS

# %%
dirN='data/crosstalk_u3m_input.txt'
ylabel='u3m'#'$\lambda_{\mu_{34}-|mtROS}$'
xlabel='input'#'Input to Snail'

title='Input and $\lambda_{\mu_{34}-|mtROS}$'
fsave='figures/crosstalk_u3m_input'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave)
#plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave,onlyShowHybrid='EM')

#for i in range(1,10):
#    fsave='figures/crosstalk_input_u3m_0_'+str(i)
#    las = i*0.1
#    plotICSvlambda_Input(dirN,xlabel,title,fsave,links=1,lAS=las)
# Out:
# Values for  0 = [[45000.0, 0.1], [55000.0, 0.1], [45000.0, 0.1], [55000.0, 0.1], [45000.0, 0.2], [55000.0, 0.2], [55000.0, 0.1], [65000.0, 0.172]]
# 45000.0 65000.0 0.1 0.2
# Locs  [[4.50e+04 1.00e-01]
#  [5.50e+04 1.00e-01]
#  [4.50e+04 1.00e-01]
#  [5.50e+04 1.00e-01]
#  [4.50e+04 2.00e-01]
#  [5.50e+04 2.00e-01]
#  [5.50e+04 1.00e-01]
#  [6.50e+04 1.72e-01]]
# Values for  1 = [[45000.0, 0.34850000000000003], [55000.0, 0.397], [45000.0, 0.397], [55000.0, 0.397]]
# 45000.0 55000.0 0.34850000000000003 0.397
# Values for  2 = [[45000.0, 0.2], [55000.0, 0.2]]
# 45000.0 55000.0 0.2 0.2
# Values for  3 = [[45000.0, 0.397], [55000.0, 0.397], [45000.0, 0.4], [55000.0, 0.4], [45000.0, 0.4], [55000.0, 0.4], [45000.0, 0.5], [55000.0, 0.5], [45000.0, 0.6], [55000.0, 0.6], [45000.0, 0.7], [55000.0, 0.75], [45000.0, 0.8], [55000.0, 0.8], [45000.0, 0.9], [55000.0, 0.9], [55000.0, 0.34850000000000003], [65000.0, 0.3985], [55000.0, 0.3985], [65000.0, 0.4]]
# 45000.0 65000.0 0.34850000000000003 0.9
# Locs  [[4.500e+04 3.970e-01]
#  [5.500e+04 3.970e-01]
#  [4.500e+04 4.000e-01]
#  [5.500e+04 4.000e-01]
#  [4.500e+04 4.000e-01]
#  [5.500e+04 4.000e-01]
#  [4.500e+04 5.000e-01]
#  [5.500e+04 5.000e-01]
#  [4.500e+04 6.000e-01]
#  [5.500e+04 6.000e-01]
#  [4.500e+04 7.000e-01]
#  [5.500e+04 7.500e-01]
#  [4.500e+04 8.000e-01]
#  [5.500e+04 8.000e-01]
#  [4.500e+04 9.000e-01]
#  [5.500e+04 9.000e-01]
#  [5.500e+04 3.485e-01]
#  [6.500e+04 3.985e-01]
#  [5.500e+04 3.985e-01]
#  [6.500e+04 4.000e-01]]
# Values for  4 = [[45000.0, 0.244], [55000.0, 0.244], [45000.0, 0.3], [55000.0, 0.3], [45000.0, 0.3], [55000.0, 0.3], [55000.0, 0.172], [65000.0, 0.272], [55000.0, 0.272], [65000.0, 0.34850000000000003]]
# 45000.0 65000.0 0.172 0.34850000000000003
# Locs  [[4.500e+04 2.440e-01]
#  [5.500e+04 2.440e-01]
#  [4.500e+04 3.000e-01]
#  [5.500e+04 3.000e-01]
#  [4.500e+04 3.000e-01]
#  [5.500e+04 3.000e-01]
#  [5.500e+04 1.720e-01]
#  [6.500e+04 2.720e-01]
#  [5.500e+04 2.720e-01]
#  [6.500e+04 3.485e-01]]
# Values for  5 = [[45000.0, 0.3], [55000.0, 0.3], [45000.0, 0.3], [55000.0, 0.3], [45000.0, 0.3], [55000.0, 0.3]]
# 45000.0 55000.0 0.3 0.3
# Values for  6 = [[45000.0, 0.244], [55000.0, 0.244], [45000.0, 0.244], [55000.0, 0.244]]
# 45000.0 55000.0 0.244 0.244
# Values for  7 = [[45000.0, 0.4], [55000.0, 0.4], [45000.0, 0.4], [55000.0, 0.4], [45000.0, 0.4], [55000.0, 0.4], [45000.0, 0.5], [55000.0, 0.5], [45000.0, 0.6], [55000.0, 0.6], [45000.0, 0.7], [55000.0, 0.7], [45000.0, 0.8], [55000.0, 0.8], [45000.0, 0.9], [55000.0, 0.9]]
# 45000.0 55000.0 0.4 0.9

# %% [markdown]
# # Triple links

# %% [markdown]
# ## AMPK -| Snail and Hif1-> Snail

# %%
dirN='data/crosstalk_AS_HS_input.txt'
xlabel='AS'#'$\lambda_{AS}$'
ylabel='HS'#'$\lambda_{HS}$'
title='AMPK  $-|$  Snail  and  HIF-1a $->$ Snail input'
for i in [0,10000,20000,30000,40000,50000]:
    fsave='figures/crosstalk_AS_HS_input_'+str(i)
    constants={'Input':[i]}
    plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave,constants)
    #plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave,checkRanges=True)
    #plotICSvlambda_doubleLink(dirN,title,fsave)
# Out:
# Values for  0 = [[0.15000000000000002, 1.5], [0.25, 2.5]]
# 0.15000000000000002 0.25 1.5 2.5
# Values for  1 = [[0.15000000000000002, 1.0], [0.25, 1.5], [0.6499999999999999, 6.5], [0.75, 7.5], [0.6499999999999999, 7.5], [0.75, 8.5]]
# 0.15000000000000002 0.75 1.0 8.5
# Locs  [[0.15 1.  ]
#  [0.25 1.5 ]
#  [0.65 6.5 ]
#  [0.75 7.5 ]
#  [0.65 7.5 ]
#  [0.75 8.5 ]]
# Values for  0 = [[0.75, 5.5], [0.8500000000000001, 6.5]]
# 0.75 0.8500000000000001 5.5 6.5
# Values for  1 = [[0.05, 1.0], [0.15000000000000002, 1.5], [0.05, 2.5], [0.15000000000000002, 3.5], [0.8500000000000001, 1.5], [0.9, 2.5]]
# 0.05 0.9 1.0 3.5
# Locs  [[0.05 1.  ]
#  [0.15 1.5 ]
#  [0.05 2.5 ]
#  [0.15 3.5 ]
#  [0.85 1.5 ]
#  [0.9  2.5 ]]
# Values for  0 = [[0.25, 6.5], [0.35, 7.5]]
# 0.25 0.35 6.5 7.5
# Values for  1 = [[0.15000000000000002, 6.5], [0.25, 7.5], [0.15000000000000002, 8.5], [0.25, 9.0], [0.8500000000000001, 7.5], [0.9, 8.5]]
# 0.15000000000000002 0.9 6.5 9.0
# Locs  [[0.15 6.5 ]
#  [0.25 7.5 ]
#  [0.15 8.5 ]
#  [0.25 9.  ]
#  [0.85 7.5 ]
#  [0.9  8.5 ]]
# Values for  0 = [[0.0, 7.5], [0.05, 8.5]]
# 0.0 0.05 7.5 8.5
# Values for  1 = [[0.0, 2.5], [0.05, 3.5], [0.25, 3.5], [0.35, 4.5], [0.8500000000000001, 5.5], [0.9, 6.5]]
# 0.0 0.9 2.5 6.5
# Locs  [[0.   2.5 ]
#  [0.05 3.5 ]
#  [0.25 3.5 ]
#  [0.35 4.5 ]
#  [0.85 5.5 ]
#  [0.9  6.5 ]]
# Values for  0 = [[0.0, 4.5], [0.05, 5.5]]
# 0.0 0.05 4.5 5.5
# Values for  1 = [[0.35, 1.5], [0.45, 2.5], [0.45, 1.5], [0.55, 2.5], [0.55, 8.5], [0.6499999999999999, 9.0]]
# 0.35 0.6499999999999999 1.5 9.0
# Locs  [[0.35 1.5 ]
#  [0.45 2.5 ]
#  [0.45 1.5 ]
#  [0.55 2.5 ]
#  [0.55 8.5 ]
#  [0.65 9.  ]]
# Values for  0 = [[0.55, 5.5], [0.6499999999999999, 6.05]]
# 0.55 0.6499999999999999 5.5 6.05
# Values for  1 = [[0.0, 1.0], [0.05, 1.5], [0.15000000000000002, 1.5], [0.25, 2.5], [0.45, 6.5], [0.55, 7.5]]
# 0.0 0.55 1.0 7.5
# Locs  [[0.   1.  ]
#  [0.05 1.5 ]
#  [0.15 1.5 ]
#  [0.25 2.5 ]
#  [0.45 6.5 ]
#  [0.55 7.5 ]]

# %% [markdown]
# ## u34 -> mtROS and Hif1-| u200

# %%
dirN='data/crosstalk_u3m_iHu_input.txt'
ylabel='u3m'#$\lambda_{\mu_{34}->mtROS}$'
xlabel='Hu'#$\lambda_{Hif1-|\mu_{200}}$'


title='$\mu_{34}->$  mtROS  and  HIF-1a $->\mu_{200}$  input'
for i in [0,10000,20000,30000,40000,50000]:
    fsave='figures/crosstalk_u3m_Hu_input_'+str(i)
    constants={'Input':[i]}
    plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave,constants)
    #plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave,checkRanges=True)
    #plotICSvlambda_doubleLink(dirN,title,fsave)
# Out:
# Values for  0 = [[0.0, 0.34850000000000003], [0.05, 0.3985], [0.05, 0.1], [0.1, 0.172], [0.05, 0.3985], [0.1, 0.4]]
# 0.0 0.1 0.1 0.4
# Locs  [[0.     0.3485]
#  [0.05   0.3985]
#  [0.05   0.1   ]
#  [0.1    0.172 ]
#  [0.05   0.3985]
#  [0.1    0.4   ]]
# Values for  1 = [[0.0, 0.272], [0.05, 0.34850000000000003]]
# 0.0 0.05 0.272 0.34850000000000003
# Values for  0 = [[0.0, 0.172], [0.05, 0.272], [0.0, 0.34850000000000003], [0.05, 0.3985], [0.0, 0.3985], [0.05, 0.4]]
# 0.0 0.05 0.172 0.4
# Values for  1 = [[0.0, 0.272], [0.05, 0.34850000000000003]]
# 0.0 0.05 0.272 0.34850000000000003
# Values for  0 = [[0.0, 0.1], [0.05, 0.172], [0.0, 0.272], [0.05, 0.34850000000000003], [0.0, 0.34850000000000003], [0.05, 0.3985]]
# 0.0 0.05 0.1 0.3985
# Values for  1 = [[0.05, 0.1], [0.1, 0.172]]
# 0.05 0.1 0.1 0.172
# Values for  0 = [[0.0, 0.272], [0.05, 0.34850000000000003], [0.05, 0.1], [0.1, 0.172], [0.05, 0.34850000000000003], [0.1, 0.397]]
# 0.0 0.1 0.1 0.397
# Locs  [[0.     0.272 ]
#  [0.05   0.3485]
#  [0.05   0.1   ]
#  [0.1    0.172 ]
#  [0.05   0.3485]
#  [0.1    0.397 ]]
# Values for  1 = [[0.05, 0.172], [0.1, 0.272]]
# 0.05 0.1 0.172 0.272
# Values for  0 = [[0.0, 0.1], [0.05, 0.172], [0.0, 0.172], [0.05, 0.272], [0.05, 0.1], [0.1, 0.172]]
# 0.0 0.1 0.1 0.272
# Locs  [[0.    0.1  ]
#  [0.05  0.172]
#  [0.    0.172]
#  [0.05  0.272]
#  [0.05  0.1  ]
#  [0.1   0.172]]
# Values for  1 = [[0.0, 0.34850000000000003], [0.05, 0.3985]]
# 0.0 0.05 0.34850000000000003 0.3985
# Values for  0 = [[0.0, 0.244], [0.05, 0.244], [0.0, 0.244], [0.05, 0.244], [0.0, 0.244], [0.05, 0.272], [0.0, 0.3], [0.05, 0.3], [0.0, 0.3], [0.05, 0.3], [0.0, 0.3], [0.05, 0.34850000000000003], [0.05, 0.244], [0.1, 0.244], [0.05, 0.244], [0.1, 0.244], [0.05, 0.244], [0.1, 0.244], [0.05, 0.272], [0.1, 0.3], [0.05, 0.3], [0.1, 0.3], [0.05, 0.3], [0.1, 0.34850000000000003]]
# 0.0 0.1 0.244 0.34850000000000003
# Locs  [[0.     0.244 ]
#  [0.05   0.244 ]
#  [0.     0.244 ]
#  [0.05   0.244 ]
#  [0.     0.244 ]
#  [0.05   0.272 ]
#  [0.     0.3   ]
#  [0.05   0.3   ]
#  [0.     0.3   ]
#  [0.05   0.3   ]
#  [0.     0.3   ]
#  [0.05   0.3485]
#  [0.05   0.244 ]
#  [0.1    0.244 ]
#  [0.05   0.244 ]
#  [0.1    0.244 ]
#  [0.05   0.244 ]
#  [0.1    0.244 ]
#  [0.05   0.272 ]
#  [0.1    0.3   ]
#  [0.05   0.3   ]
#  [0.1    0.3   ]
#  [0.05   0.3   ]
#  [0.1    0.3485]]
# Values for  1 = [[0.0, 0.34850000000000003], [0.05, 0.397], [0.0, 0.397], [0.05, 0.397], [0.0, 0.397], [0.05, 0.3985], [0.0, 0.3985], [0.05, 0.4], [0.0, 0.4], [0.05, 0.4], [0.0, 0.4], [0.05, 0.4], [0.05, 0.397], [0.1, 0.397]]
# 0.0 0.1 0.34850000000000003 0.4
# Locs  [[0.     0.3485]
#  [0.05   0.397 ]
#  [0.     0.397 ]
#  [0.05   0.397 ]
#  [0.     0.397 ]
#  [0.05   0.3985]
#  [0.     0.3985]
#  [0.05   0.4   ]
#  [0.     0.4   ]
#  [0.05   0.4   ]
#  [0.     0.4   ]
#  [0.05   0.4   ]
#  [0.05   0.397 ]
#  [0.1    0.397 ]]

# %% [markdown]
# ## u34 -> mt/noxROS and Hif1-> Snail

# %%
dirN='data/crosstalk_u3n_u3m_HS_input.txt'
