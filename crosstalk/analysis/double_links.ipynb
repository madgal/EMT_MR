# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import Normalize
import os
import math
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

# %%
from aux_func_States import *
from functions_for_plotting import *

# %%
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams.update({'font.size': 20})

# %%
dirN='data/crosstalk_iHu_u3m.txt'
xlabel='Hu'#'$\lambda_{Hu}$'
ylabel='u3m'#'$\lambda_{u3m}$'
title='Hif-1  $-| \mu_{200}$   and   $ \mu_{34}->$ mtROS'
fsave='figures/crosstalk_iHu_u3m'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave)
#plotICSvlambda_doubleLink(dirN,xlabel,title,fsave,plotBasedThresh=True)
# Out:
# [[['M/W', 'M/WO', 'M/O'], '#e6194b'], [['M/W', 'M/WO', 'M/O', 'EM/O'], '#3cb44b'], [['M/W', 'M/WO', 'M/O', 'EM/O', 'E/O'], '#ffe119'], [['M/W', 'M/WO', 'M/O', 'EM/W'], '#4363d8'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'E/W'], '#f58231'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'EM/O', 'E/O'], '#911eb4'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'EM/O', 'E/WO', 'E/O'], '#46f0f0'], [['M/W', 'M/WO', 'M/O', 'EM/WO', 'EM/O'], '#f032e6'], [['M/W', 'M/WO', 'M/O', 'EM/WO', 'EM/O', 'E/O'], '#bcf60c'], [['M/W', 'M/WO', 'M/O', 'EM/WO', 'EM/O', 'E/WO'], '#fabebe'], [['M/W', 'M/WO', 'M/O', 'EM/WO', 'EM/O', 'E/WO', 'E/O'], '#008080']]
# ['#008080' '#3cb44b' '#4363d8' '#46f0f0' '#911eb4' '#bcf60c' '#e6194b'
#  '#f032e6' '#f58231' '#fabebe' '#ffe119']
# 0.1 0.25 0.1 0.172 #e6194b
# 0.1 0.25 0.172 0.272 #3cb44b
# 0.1 0.25 0.272 0.34850000000000003 #3cb44b
# 0.1 0.25 0.34850000000000003 0.3985 #3cb44b
# 0.1 0.25 0.3985 0.4 #3cb44b
# 0.25 0.55 0.1 0.172 #e6194b
# 0.25 0.55 0.172 0.272 #3cb44b
# ...

# %% [markdown]
# ## AMPK -| Snail and Hif1->Snail

# %%
dirN='data/crosstalk_AS_HS.txt'
xlabel='AS'#'$\lambda_{AS}$'
ylabel='HS'#'$\lambda_{HS}$'
title='AMPK  $-|$  Snail  and  HIF-1a $->$ Snail'
fsave='figures/crosstalk_AS_HS'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave)
#plotICSvlambda_doubleLink(dirN,xlabel,title,fsave)
# Out:
# [[['E/W', 'E/WO', 'E/O'], '#e6194b'], [['M/O', 'E/W', 'E/WO', 'E/O'], '#3cb44b'], [['M/W', 'M/WO', 'E/O'], '#ffe119'], [['M/W', 'M/WO', 'M/O', 'E/O'], '#4363d8'], [['M/W', 'M/WO', 'M/O', 'EM/O', 'E/O'], '#f58231']]
# ['#3cb44b' '#4363d8' '#e6194b' '#f58231' '#ffe119']
# 0.5 0.55 0.0 0.005 #e6194b
# 0.5 0.55 0.005 0.015 #e6194b
# 0.5 0.55 0.015 0.51 #e6194b
# 0.5 0.55 0.51 1.5 #ffe119
# 0.5 0.55 1.5 2.5 #ffe119
# 0.5 0.55 2.5 3.05 #ffe119
# 0.5 0.55 3.05 3.1500000000000004 #ffe119
# 0.5 0.55 3.1500000000000004 4.6 #ffe119
# 0.5 0.55 4.6 6.05 #ffe119
# 0.5 0.55 6.05 6.15 #ffe119
# 0.5 0.55 6.15 7.6 #ffe119
# 0.5 0.55 7.6 9.05 #ffe119
# 0.5 0.55 9.05 9.149999999999999 #ffe119
# 0.5 0.55 9.149999999999999 9.2 #ffe119
# 0.55 0.6499999999999999 0.0 0.005 #e6194b
# 0.55 0.6499999999999999 0.005 0.015 #e6194b
# 0.55 0.6499999999999999 0.015 0.51 #e6194b
# 0.55 0.6499999999999999 0.51 1.5 #ffe119
# 0.55 0.6499999999999999 1.5 2.5 #ffe119
# 0.55 0.6499999999999999 2.5 3.05 #ffe119
# ...

# %% [markdown]
# ## AMPK -> u200 and Hif1->Snail

# %%
dirN='data/crosstalk_Au_HS.txt'
xlabel='Au'#'$\lambda_{Au}$'
ylabel='HS'#'$\lambda_{HS}$'
title='AMPK  $-> \mu_{200}$   and  HIF-1a $->$ Snail'
fsave='figures/crosstalk_Au_HS'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave)
#plotICSvlambda_doubleLink(dirN,xlabel,title,fsave)
# Out:
# [[['E/W', 'E/WO', 'E/O'], '#e6194b'], [['M/W', 'E/W', 'E/WO', 'E/O'], '#3cb44b'], [['M/W', 'M/WO', 'E/O'], '#ffe119'], [['M/W', 'M/WO', 'E/W', 'E/WO', 'E/O'], '#4363d8'], [['M/W', 'M/WO', 'E/WO', 'E/O'], '#f58231'], [['M/W', 'M/WO', 'EM/W', 'E/W', 'E/WO', 'E/O'], '#911eb4'], [['M/W', 'M/WO', 'EM/WO', 'E/O'], '#46f0f0'], [['M/W', 'M/WO', 'M/O'], '#f032e6'], [['M/W', 'M/WO', 'M/O', 'E/O'], '#bcf60c'], [['M/W', 'M/WO', 'M/O', 'E/W', 'E/WO', 'E/O'], '#fabebe'], [['M/W', 'M/WO', 'M/O', 'EM/O'], '#008080'], [['M/W', 'M/WO', 'M/O', 'EM/O', 'E/O'], '#e6beff'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'E/W', 'E/WO', 'E/O'], '#9a6324'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'E/W', 'E/WO', 'E/O'], '#fffac8'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'E/WO', 'E/O'], '#800000'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'EM/O', 'E/O'], '#aaffc3'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'EM/O', 'E/W', 'E/WO', 'E/O'], 'k'], [['M/W', 'M/WO', 'M/O', 'EM/WO', 'E/O'], '#ffd8b1'], [['M/W', 'M/WO', 'M/O', 'EM
# ...

# %% [markdown]
# ## u34->nox/mtROS

# %%
dirN='data/crosstalk_u3n_u3m.txt'
xlabel='u3m'#'$\lambda_{u3n}$'
ylabel='u3n'#'$\lambda_{u3m}$'
title='$\mu_{34}->$ noxROS   and   $ \mu_{34}->$ mtROS'
fsave='figures/crosstalk_u3n_u3m'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave)
#plotICSvlambda_doubleLink(dirN,xlabel,title,fsave)
# Out:
# [[['M/W', 'M/WO', 'M/O', 'EM/W', 'E/W'], '#e6194b'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/O', 'E/W'], '#3cb44b'], [['M/W', 'M/WO', 'M/O', 'EM/WO', 'EM/O', 'E/WO'], '#ffe119'], [['M/W', 'M/WO', 'M/O', 'EM/WO', 'EM/O', 'E/WO', 'E/O'], '#4363d8'], [['M/WO', 'M/O', 'EM/W', 'E/W'], '#f58231'], [['M/WO', 'M/O', 'EM/WO', 'E/WO'], '#911eb4'], [['M/WO', 'M/O', 'EM/WO', 'EM/O', 'E/WO', 'E/O'], '#46f0f0']]
# ['#3cb44b' '#4363d8' '#46f0f0' '#911eb4' '#e6194b' '#f58231' '#ffe119']
# 0.1 0.172 0.0 0.15 #911eb4
# 0.1 0.172 0.15 0.40249999999999997 #f58231
# 0.1 0.172 0.40249999999999997 0.6325000000000001 #e6194b
# 0.1 0.172 0.6325000000000001 0.76 #e6194b
# 0.172 0.272 0.0 0.15 #911eb4
# 0.172 0.272 0.15 0.40249999999999997 #f58231
# 0.172 0.272 0.40249999999999997 0.6325000000000001 #3cb44b
# 0.172 0.272 0.6325000000000001 0.76 #ffe119
# 0.272 0.34850000000000003 0.0 0.15 #46f0f0
# 0.272 0.34850000000000003 0.15 0.40249999999999997 #46f0f0
# ...

# %% [markdown]
# ## AMPK -> u200 and u34 -> mtROS

# %%
dirN='data/crosstalk_Au_u3m.txt'
xlabel='Au'#'$\lambda_{Au}$'
ylabel='u3m'#'$\lambda_{u3m}$'
title='AMPK  $-> \mu_{200}$   and   $ \mu_{34}->$ mtROS'
fsave='figures/crosstalk_Au_u3m'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave)
#plotICSvlambda_doubleLink(dirN,xlabel,title,fsave,plotBasedThresh=True)
# Out:
# [[['E/W'], '#e6194b'], [['E/W', 'E/WO', 'E/O'], '#3cb44b'], [['E/WO'], '#ffe119'], [['E/WO', 'E/O'], '#4363d8'], [['M/W', 'E/W', 'E/WO', 'E/O'], '#f58231'], [['M/W', 'E/WO'], '#911eb4'], [['M/W', 'E/WO', 'E/O'], '#46f0f0'], [['M/W', 'M/WO', 'E/W'], '#f032e6'], [['M/W', 'M/WO', 'E/W', 'E/WO', 'E/O'], '#bcf60c'], [['M/W', 'M/WO', 'E/WO'], '#fabebe'], [['M/W', 'M/WO', 'E/WO', 'E/O'], '#008080'], [['M/W', 'M/WO', 'M/O', 'E/W'], '#e6beff'], [['M/W', 'M/WO', 'M/O', 'E/W', 'E/WO', 'E/O'], '#9a6324'], [['M/W', 'M/WO', 'M/O', 'E/WO'], '#fffac8'], [['M/W', 'M/WO', 'M/O', 'E/WO', 'E/O'], '#800000'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'E/W'], '#aaffc3'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'E/W', 'E/WO', 'E/O'], '#808000'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'E/WO', 'E/O'], '#ffd8b1'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'E/W', 'E/WO', 'E/O'], '#000075'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'E/WO', 'E/O'], '#808080'], [['M/W', 'M/WO', 'M/O', 'EM/WO', 'E/WO'], '#ffffff'], [['M/W', 'M/WO', 'M/O', 
# ...

# %% [markdown]
# ## Hif1-| u200 and Hif1->Snail

# %%
dirN='data/crosstalk_iHu_HS.txt'
xlabel='Hu'#'$\lambda_{Hu}$'
ylabel='HS'#'$\lambda_{HS}$'
title='Hif-1  $-| \mu_{200}$   and  HIF-1a $->$ Snail'
fsave='figures/crosstalk_iHu_HS'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave)
#plotICSvlambda_doubleLink(dirN,xlabel,title,fsave,plotBasedThresh=True)
# Out:
# [[['M/W', 'M/WO', 'M/O'], '#e6194b'], [['M/W', 'M/WO', 'M/O', 'EM/O'], '#3cb44b'], [['M/W', 'M/WO', 'M/O', 'EM/O', 'E/O'], '#ffe119'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'EM/O', 'E/O'], '#4363d8'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'EM/O', 'E/W', 'E/WO', 'E/O'], 'k'], [['M/W', 'M/WO', 'M/O', 'EM/WO', 'EM/O', 'E/O'], '#911eb4']]
# ['#3cb44b' '#4363d8' '#911eb4' '#e6194b' '#ffe119' 'k']
# 0.1 0.25 1.0 1.05 #3cb44b
# 0.1 0.25 1.05 1.13 #3cb44b
# 0.1 0.25 1.13 1.19 #3cb44b
# 0.1 0.25 1.19 2.11 #3cb44b
# 0.1 0.25 2.11 4.55 #3cb44b
# 0.1 0.25 4.55 10.55 #e6194b
# 0.1 0.25 10.55 15.0 #e6194b
# 0.25 0.55 1.0 1.05 #ffe119
# 0.25 0.55 1.05 1.13 #ffe119
# 0.25 0.55 1.13 1.19 #ffe119
# 0.25 0.55 1.19 2.11 #ffe119
# 0.25 0.55 2.11 4.55 #3cb44b
# 0.25 0.55 4.55 10.55 #3cb44b
# 0.25 0.55 10.55 15.0 #e6194b
# 0.55 0.75 1.0 1.05 #911eb4
# 0.55 0.75 1.05 1.13 #ffe119
# 0.55 0.75 1.13 1.19 #ffe119
# 0.55 0.75 1.19 2.11 #ffe119
# 0.55 0.75 2.11 4.55 #ffe119
# 0.55 0.75 4.55 10.55 #3cb44b
# ...

# %% [markdown]
# ## Hif1-|u200 and u34->mtROS

# %% [markdown]
# ## Hif1-| u200 and u200 -| Hif1

# %%
dirN='data/crosstalk_iHu_uH.txt'
xlabel='Hu'#'$\lambda_{Hu}$'
ylabel='uh'#'$\mu_{200} reg. Hif1$'
title='HIF-1  $-| \mu_{200}$   and   $ \mu_{200}->$ HIF-1'
fsave='figures/crosstalk_iHu_uh'
plotCoupledPhenotypes_doubleLink(dirN,xlabel,ylabel,title,fsave)#,plotBasedThresh=False,ylim=[0,10])
#plotICSvlambda_doubleLink(dirN,xlabel,title,fsave,plotBasedThresh=True)
# Out:
# [[['M/O', 'EM/O', 'E/O'], '#e6194b'], [['M/W', 'M/WO', 'M/O', 'EM/O'], '#3cb44b'], [['M/W', 'M/WO', 'M/O', 'EM/O', 'E/O'], '#ffe119'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'EM/O', 'E/O'], '#4363d8'], [['M/W', 'M/WO', 'M/O', 'EM/W', 'EM/WO', 'EM/O', 'E/W', 'E/WO', 'E/O'], 'k'], [['M/W', 'M/WO', 'M/O', 'EM/WO', 'EM/O', 'E/O'], '#911eb4']]
# ['#3cb44b' '#4363d8' '#911eb4' '#e6194b' '#ffe119' 'k']
# 0.5 1.5 0.13074625606596854 0.13081550938548991 #e6194b
# 0.5 1.5 0.13081550938548991 0.13099980495936564 #e6194b
# 0.5 1.5 0.13099980495936564 0.1314276275112477 #e6194b
# 0.5 1.5 0.1314276275112477 0.13179833121229295 #e6194b
# 0.5 1.5 0.13179833121229295 0.13186827504893622 #e6194b
# 0.5 1.5 0.13186827504893622 0.13198447352696763 #e6194b
# 0.5 1.5 0.13198447352696763 0.1320886515718733 #e6194b
# 0.5 1.5 0.1320886515718733 0.1321006630663915 #e6194b
# 0.5 1.5 0.1321006630663915 0.1321922779883465 #e6194b
# 0.5 1.5 0.1321922779883465 0.13234163004115898 #e6194b
# ...
