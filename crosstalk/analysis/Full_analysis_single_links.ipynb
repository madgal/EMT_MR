# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import Normalize
import os
import math
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

# %%
from aux_func_States import *

from functions_for_plotting import *

# %%
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams.update({'font.size': 20})

# %%
dirN='data/crosstalk_iHu.txt'
xlabel='Hu'#'$\lambda_{Hu}$'
title='Hif1  $-| \mu_{200}$ '
fsave='figures/crosstalk_iHu'
plotCoupledPhenotypes_singleLink(dirN,xlabel,title,fsave)
plotICSvlambda_singleLink(dirN,xlabel,title,fsave)
# Out:
# 28 Index([u'AS', u'AZ', u'AU', u'HS', u'HU', u'INPUT', u'U3M', u'U3N', u'UH',
#        u'E', u'EM', u'M', u'W', u'WO', u'O', u'M/W', u'M/WO', u'M/O', u'EM/W',
#        u'EM/WO', u'EM/O', u'E/W', u'E/WO', u'E/O', u'nics'],
#       dtype='object')

# %%
dirN='data/crosstalk_AZ.txt'
xlabel='AZ'#'$\lambda_{AZ}$'
title='AMPK  $-|$  Zeb'
fsave='figures/crosstalk_AZ'
plotCoupledPhenotypes_singleLink(dirN,xlabel,title,fsave)
plotICSvlambda_singleLink(dirN,xlabel,title,fsave)

dirN='data/crosstalk_AS.txt'
xlabel='AS'#'$\lambda_{AS}$'
title='AMPK  $-|$  Snail'
fsave='figures/crosstalk_AS'
plotCoupledPhenotypes_singleLink(dirN,xlabel,title,fsave)
plotICSvlambda_singleLink(dirN,xlabel,title,fsave)

dirN='data/crosstalk_Au.txt'
xlabel='Au'#'$\lambda_{Au}$'
title='AMPK  $-> \mu_{200}$ '
fsave='figures/crosstalk_Au'
plotCoupledPhenotypes_singleLink(dirN,xlabel,title,fsave)
plotICSvlambda_singleLink(dirN,xlabel,title,fsave)

dirN='data/crosstalk_HS.txt'
xlabel='HS'#'$\lambda_{HS}$'
title='Hif1  $-> Snail$ '
fsave='figures/crosstalk_HS'
plotCoupledPhenotypes_singleLink(dirN,xlabel,title,fsave)
plotICSvlambda_singleLink(dirN,xlabel,title,fsave)
  

dirN='data/crosstalk_u3m.txt'
xlabel='u3m'#'$\lambda_{u3m}$'
title='$ \mu_{34}-> mtROS$ '
fsave='figures/crosstalk_u3m'
plotCoupledPhenotypes_singleLink(dirN,xlabel,title,fsave)
#plotCoupledPhenotypes_singleLink_grouped(dirN,xlabel,title,fsave,'MR')
plotICSvlambda_singleLink(dirN,xlabel,title,fsave)
    
dirN='data/crosstalk_u3n.txt'
xlabel='u3n'#$\lambda_{u3n}$'
title='$ \mu_{34}-> noxROS$ '
fsave='figures/crosstalk_u3n'
plotCoupledPhenotypes_singleLink(dirN,xlabel,title,fsave)
#plotCoupledPhenotypes_singleLink_grouped(dirN,xlabel,title,fsave,'MR')
plotICSvlambda_singleLink(dirN,xlabel,title,fsave)
# Out:
# 37 Index([u'AS', u'AZ', u'AU', u'HS', u'HU', u'INPUT', u'U3M', u'U3N', u'UH',
#        u'E', u'EM', u'M', u'W', u'WO', u'O', u'M/W', u'M/WO', u'M/O', u'EM/W',
#        u'EM/WO', u'EM/O', u'E/W', u'E/WO', u'E/O', u'nics'],
#       dtype='object')
# 46 Index([u'AS', u'AZ', u'AU', u'HS', u'HU', u'INPUT', u'U3M', u'U3N', u'UH',
#        u'E', u'EM', u'M', u'W', u'WO', u'O', u'M/W', u'M/WO', u'M/O', u'EM/W',
#        u'EM/WO', u'EM/O', u'E/W', u'E/WO', u'E/O', u'nics'],
#       dtype='object')
# 27 Index([u'AS', u'AZ', u'AU', u'HS', u'HU', u'INPUT', u'U3M', u'U3N', u'UH',
#        u'E', u'EM', u'M', u'W', u'WO', u'O', u'M/W', u'M/WO', u'M/O', u'EM/W',
#        u'EM/WO', u'EM/O', u'E/W', u'E/WO', u'E/O', u'nics'],
#       dtype='object')
# 55 Index([u'AS', u'AZ', u'AU', u'HS', u'HU', u'INPUT', u'U3M', u'U3N', u'UH',
#        u'E', u'EM', u'M', u'W', u'WO', u'O', u'M/W', u'M/WO', u'M/O', u'EM/W',
#        u'EM/WO', u'EM/O', u'E/W', u'E/WO', u'E/O', u'nics'],
#       dtype='object')
# ...

# %%
for i in range(1,8):
    fileN = "data/crosstalk_uh"+str(i)+".txt"
    title ='uh'+str(i)
    fsave='figures/crosstalk_uh'+str(i)
    xlabel='uH'
    plotCoupledPhenotypes_singleLink(fileN,xlabel,title,fsave)
# Out:
# 294 Index([u'AS', u'AZ', u'AU', u'HS', u'HU', u'INPUT', u'U3M', u'U3N', u'UH',
#        u'E', u'EM', u'M', u'W', u'WO', u'O', u'M/W', u'M/WO', u'M/O', u'EM/W',
#        u'EM/WO', u'EM/O', u'E/W', u'E/WO', u'E/O', u'nics'],
#       dtype='object')
# 294 Index([u'AS', u'AZ', u'AU', u'HS', u'HU', u'INPUT', u'U3M', u'U3N', u'UH',
#        u'E', u'EM', u'M', u'W', u'WO', u'O', u'M/W', u'M/WO', u'M/O', u'EM/W',
#        u'EM/WO', u'EM/O', u'E/W', u'E/WO', u'E/O', u'nics'],
#       dtype='object')
# 294 Index([u'AS', u'AZ', u'AU', u'HS', u'HU', u'INPUT', u'U3M', u'U3N', u'UH',
#        u'E', u'EM', u'M', u'W', u'WO', u'O', u'M/W', u'M/WO', u'M/O', u'EM/W',
#        u'EM/WO', u'EM/O', u'E/W', u'E/WO', u'E/O', u'nics'],
#       dtype='object')
# 294 Index([u'AS', u'AZ', u'AU', u'HS', u'HU', u'INPUT', u'U3M', u'U3N', u'UH',
#        u'E', u'EM', u'M', u'W', u'WO', u'O', u'M/W', u'M/WO', u'M/O', u'EM/W',
#        u'EM/WO', u'EM/O', u'E/W', u'E/WO', u'E/O', u'nics'],
#       dtype='object')
# ...
