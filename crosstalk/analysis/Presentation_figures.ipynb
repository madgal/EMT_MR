# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import Normalize
import os
import math
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

# %%
from aux_func_thresholdsAndStates import *

#from functions_for_plotting import *

# %%
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams.update({'font.size': 20})

# %%
thresholds=stateThresholds()#thresholdsV2("../coupledWReg_Ccode/crosstalk_u3m/EMT_MR_comp_0_392_1000_res.txt")
df = pd.read_csv("../coupledWReg_Ccode/crosstalk_comparison/EMT_MR_comp_0_1000_res.txt").dropna()
 
fs=30
fig,(ax2) = plt.subplots(1,1,figsize=(10,11))
plt.subplots_adjust(hspace=0.2,wspace=0.5)

labels={"u":"$\mu_{200}$ (molecules)",'mz':'Zeb mNRA (molecules)','A':'AMPK (nmol/L)','h':'Hif-1 (nmol/L)'}
x2L = 'A'
y2L='mz'
x2m=np.max([1000,np.max(df[x2L].values)])
y2m=np.max([1200,np.max(df[y2L].values)])
x2v=np.arange(0,x2m)
y2v=np.arange(0,y2m)
df_comp =pd.read_csv("../coupledWReg_Ccode/crosstalk_comparison/EMT_MR_comp_0_1000_res.txt").dropna()
ax2.plot(df_comp[x2L].values,df_comp[y2L].values,"ro",markersize=10)
ax2.plot(df[x2L].values,df[y2L].values,"ko",markersize=10)

y2a= thresholds['EM'][y2L][0]
y2b=thresholds['EM'][y2L][1]
ax2.fill_between(x2v,y2a, y2b,facecolor='blue',alpha=0.4)#
ax2.set_ylabel(labels[y2L],fontsize=fs)

plt.text(1.05,.8, 'M', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(1.05,.35, 'EM', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(1.05,.08, 'E', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)

x2a= thresholds['WO'][x2L][0]
x2b= thresholds['WO'][x2L][1]
ax2.fill_betweenx(y2v,x2a, x2b,facecolor='red',alpha=0.4)#
ax2.set_xlabel(labels[x2L],fontsize=fs)
plt.text(.15, 1.05 , 'W', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(.5, 1.05 , 'WO', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(.85, 1.05 , 'O', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)

ax2.set_ylim(0,1200)
ax2.set_xlim(0,600)
#plt.text(.5, 1.15 , '$\lambda$=0.392', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs+10)
ax2.tick_params(labelsize=fs)
fig.savefig('inactive_pres.png',bbox_inches='tight')

# %%
thresholds=stateThresholds()#thresholdsV2("../coupledWReg_Ccode/crosstalk_u3m/EMT_MR_comp_0_392_1000_res.txt")
df = pd.read_csv("../coupledWReg_Ccode/crosstalk_u3m/EMT_MR_comp_0_392_1000_res.txt").dropna()

fs=30
fig,(ax2) = plt.subplots(1,1,figsize=(10,11))
plt.subplots_adjust(hspace=0.2,wspace=0.5)

labels={"u":"$\mu_{200}$ (molecules)",'mz':'Zeb mNRA (molecules)','A':'AMPK (nmol/L)','h':'Hif-1 (nmol/L)'}
x2L = 'A'
y2L='mz'
x2m=np.max([1000,np.max(df[x2L].values)])
y2m=np.max([1200,np.max(df[y2L].values)])
x2v=np.arange(0,x2m)
y2v=np.arange(0,y2m)
df_comp =pd.read_csv("../coupledWReg_Ccode/crosstalk_comparison/EMT_MR_comp_0_1000_res.txt").dropna()
ax2.plot(df_comp[x2L].values,df_comp[y2L].values,"ro",markersize=10)
ax2.plot(df[x2L].values,df[y2L].values,"ko",markersize=10)

y2a= thresholds['EM'][y2L][0]
y2b=thresholds['EM'][y2L][1]
ax2.fill_between(x2v,y2a, y2b,facecolor='blue',alpha=0.4)#
ax2.set_ylabel(labels[y2L],fontsize=fs)

plt.text(1.05,.8, 'M', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(1.05,.35, 'EM', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(1.05,.08, 'E', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)

x2a= thresholds['WO'][x2L][0]
x2b= thresholds['WO'][x2L][1]
ax2.fill_betweenx(y2v,x2a, x2b,facecolor='red',alpha=0.4)#
ax2.set_xlabel(labels[x2L],fontsize=fs)
plt.text(.15, 1.05 , 'W', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(.5, 1.05 , 'WO', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(.85, 1.05 , 'O', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)

ax2.set_ylim(0,1200)
ax2.set_xlim(0,600)
plt.text(.5, 1.15 , '$\lambda$=0.392', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs+10)
ax2.tick_params(labelsize=fs)
fig.savefig('u3m_pres.png',bbox_inches='tight')

# %%
thresholds=stateThresholds()#thresholdsV2("../coupledWReg_Ccode/crosstalk_u3n_u3m/EMT_MR_comp_u3m_0_400_u3n_0_300_1000_res.txt")
df = pd.read_csv("../coupledWReg_Ccode/crosstalk_u3n_u3m/EMT_MR_comp_u3m_0_400_u3n_0_300_1000_res.txt").dropna()

fs=30
fig,(ax2) = plt.subplots(1,1,figsize=(10,11))
plt.subplots_adjust(hspace=0.2,wspace=0.5)

labels={"u":"$\mu_{200}$ (molecules)",'mz':'Zeb mNRA (molecules)','A':'AMPK (nmol/L)','h':'Hif-1 (nmol/L)'}
x2L = 'A'
y2L='mz'
x2m=np.max([1000,np.max(df[x2L].values)])
y2m=np.max([1200,np.max(df[y2L].values)])
x2v=np.arange(0,x2m)
y2v=np.arange(0,y2m)
df_comp =pd.read_csv("../coupledWReg_Ccode/crosstalk_comparison/EMT_MR_comp_0_1000_res.txt").dropna()
ax2.plot(df_comp[x2L].values,df_comp[y2L].values,"ro",markersize=10)
ax2.plot(df[x2L].values,df[y2L].values,"ko",markersize=10)

y2a= thresholds['EM'][y2L][0]
y2b=thresholds['EM'][y2L][1]
ax2.fill_between(x2v,y2a, y2b,facecolor='blue',alpha=0.4)#
ax2.set_ylabel(labels[y2L],fontsize=fs)

plt.text(1.05,.8, 'M', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(1.05,.35, 'EM', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(1.05,.08, 'E', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)

x2a= thresholds['WO'][x2L][0]
x2b= thresholds['WO'][x2L][1]
ax2.fill_betweenx(y2v,x2a, x2b,facecolor='red',alpha=0.4)#
ax2.set_xlabel(labels[x2L],fontsize=fs)
plt.text(.15, 1.05 , 'W', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(.5, 1.05 , 'WO', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)
plt.text(.85, 1.05 , 'O', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs)

ax2.set_ylim(0,1200)
ax2.set_xlim(0,600)
plt.text(.5, 1.15 , '$\lambda_{\mu_{34}->noxROS}$=0.4', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs+10)
plt.text(.5, 1.25 , '$\lambda_{\mu_{34}->mtROS}$=0.3', horizontalalignment='center',verticalalignment='center', transform=ax2.transAxes,fontsize=fs+10)
ax2.tick_params(labelsize=fs)
fig.savefig('u3m_u3n_pres.png',bbox_inches='tight')

# %%
xval,label=[],[]
__clist=['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#ffffff', '#000000']


dirN="../coupledWReg_Ccode/crosstalk_u3m/"
for filen in os.listdir(dirN):
        if 'res.txt' in filen:
            tmp= filen.split("_")
            start=3
            if "comp" not in filen:
                start = 2
            lamda = float(tmp[start])+float(tmp[start+1])/10**(len(tmp[start+1]))
            nics=float(tmp[start+2])
            df =pd.read_csv(dirN+filen).dropna()
            if len(df)==nics:
                thresholds=stateThresholds()
                res,maxv=getStates(df,thresholds)

                tmp=[]
                for key in res:
                    if "/" in key and res[key]>0:
                        tmp+=[key]

                label+=[tmp]
                xval+=[lamda]
lens = []
for i in range(len(label)):
        lens+=[len(label[i])]
if 9 in lens:
     if 1 not in xval:
                xval+=[1.]
                ind = np.argwhere(np.array(lens)==9)[:,0][0]
                label+=[np.array(label)[ind]]
elif 1 not in xval:
        xval+=[1.]
        label+=[['E/O','E/WO','E/W','M/O','M/WO','M/W','EM/O','EM/WO','EM/W']]
inds = np.argsort(xval)
xval = np.array(xval)[inds]
label= np.array(label)[inds]
colList=np.unique(label)
color=[]
for i in range(len(label)):
        if type(colList[0])==list:
            for j in range(len(colList)):
                if equals(label[i],colList[j]):
                    if len(colList[j])!=9:
                        color+=[__clist[j]]
                    else:
                        color+=['k']
                    break
        else:
            if equals(label[i],colList):
                if len(colList)!=9:
                    color+=[__clist[0]]
                else:
                    color+=['k']


fig = plt.figure(figsize=(12,7))
yfill=np.arange(0,20)
for i in range(len(xval)):
        if i<len(xval)-1 and i>0:
            x1 = (xval[i]-xval[i-1])/2.+xval[i-1]
            x2 = (xval[i+1]-xval[i])/2.+xval[i]
            plt.fill_betweenx(yfill,x1, x2,facecolor=color[i])#
        elif i==0:
            x2 = (xval[i+1]-xval[i])/2.+xval[i]
            plt.fill_betweenx(yfill,xval[i], x2,facecolor=color[i])#
        else:
            x1 = (xval[i]-xval[i-1])/2.+xval[i-1]
            plt.fill_betweenx(yfill,x1, xval[i],facecolor=color[i])

legend_elements=[]
if type(colList[0])==list:
        for i in range(len(colList)):
            if len(colList[i])!=9:
                legend_elements += [Patch(facecolor=__clist[i], edgecolor=__clist[i],
                                         label=colList[i])]
            else:
                legend_elements += [Patch(facecolor='k', edgecolor='k',
                                         label=colList[i])]
else:
        if len(colList)!=9:
            legend_elements += [Patch(facecolor=__clist[0], edgecolor=__clist[0],
                                     label=colList[0])]
        else:
            legend_elements += [Patch(facecolor='k', edgecolor='k',
                                     label=colList)]

plt.legend(handles=legend_elements,  bbox_to_anchor=(1.05, 0.9), loc='upper left',fontsize=fs-5)
plt.title('$\mu_{34}->$mtROS',fontsize=fs)
plt.ylim(0,19)
plt.xlim(0.2,0.5)
plt.yticks([])
plt.xlabel("$\lambda_{\mu_{34}->mtROS}$",fontsize=fs+5)
plt.tick_params(labelsize=fs+5)
plt.text(0.55, 18, 'Key: Accessible states', fontsize=fs)
plt.text(0.25, -6, 'Increasing upregulation', bbox=dict(boxstyle="larrow", fc="gray", ec="k", lw=1,alpha=0.6),fontsize=fs)
fig.savefig("singCL_pres.png",bbox_inches='tight')

# %%
xval,yval,lab=[],[],[]
dirN='../coupledWReg_Ccode/crosstalk_u3n_u3m/'
for filen in os.listdir(dirN):
        if 'res.txt' in filen:
            tmp= filen.split("_")
            start=3
            if "comp" not in filen:
                start = 2
            lamdaX = float(tmp[start+1])+float(tmp[start+2])/10**(len(tmp[start+2]))
            if ('uH' in dirN) or ('uh' in dirN):
                lamdaY = float(tmp[start+4])
                nics=float(tmp[start+5])
            else:
                lamdaY = float(tmp[start+4])+float(tmp[start+5])/10**(len(tmp[start+5]))
                nics=float(tmp[start+6])
            df =pd.read_csv(dirN+filen).dropna()
            if len(df)==nics:
                thresholds=stateThresholds()
                res,maxv=getStates(df,thresholds)

                tmp=[]
                for key in res:
                    if "/" in key and res[key]>0:
                        tmp+=[key]

                lab+=[tmp]
                xval+=[lamdaX]
                yval+=[lamdaY]

inds = np.argsort(xval)
xval = np.array(xval)[inds]
yval = np.array(yval)[inds]
lab= np.array(lab)[inds]
x1,x2,y1,y2=[],[],[],[]
label=[]
tmp=np.unique(np.array(xval))
for i in range(len(tmp)):
        el=tmp[i]
        ind = np.argwhere(el==np.array(xval))[:,0]
        tmpz=np.array(lab)[ind]
        ind2= np.argsort(np.array(yval)[ind])
        tmpz=tmpz[ind2]
        tmp2=np.array(yval)[ind][ind2]
        for j in range(len(tmp2)):
                el2=tmp2[j]
                if i==0:
                    x1+=[el]
                    x2+=[(tmp[i+1]-tmp[i])/2.+tmp[i]]
                elif el==np.max(tmp):
                    x1+=[(tmp[i]-tmp[i-1])/2.+tmp[i-1]]
                    x2+=[el]
                else:
                    x1+=[(tmp[i]-tmp[i-1])/2.+tmp[i-1]]
                    x2+=[(tmp[i+1]-tmp[i])/2.+tmp[i]]
                if j==0:
                    y1+=[el2]
                    y2+=[(tmp2[j+1]-tmp2[j])/2.+tmp2[j]]
                elif el2==np.max(tmp2):
                    y1+=[(tmp2[j]-tmp2[j-1])/2.+tmp2[j-1]]
                    y2+=[el]
                else:
                    y1+=[(tmp2[j]-tmp2[j-1])/2.+tmp2[j-1]]
                    y2+=[(tmp2[j+1]-tmp2[j])/2.+tmp2[j]]
                label+=[tmpz[j]]

label=np.array(label)
colList=np.unique(label)
color=[]
for i in range(len(label)):
        if type(colList[0])==list:
            for j in range(len(colList)):
                if equals(label[i],colList[j]):
                    if len(colList[j])!=9:
                        color+=[__clist[j]]
                    else:
                        color+=['k']
                    break
        else:
            if equals(label[i],colList):
                if len(colList)!=9:
                    color+=[__clist[0]]
                else:
                    color+=['k']


fig = plt.figure(figsize=(12,7))
yfill=np.arange(0,20)
for i in range(len(x1)):
    plt.fill_between([x1[i],x2[i]],y1[i],y2[i],facecolor=color[i])

legend_elements=[]
if type(colList[0])==list:
        for i in range(len(colList)):
            if len(colList[i])!=9:
                legend_elements += [Patch(facecolor=__clist[i], edgecolor=__clist[i],
                                         label=colList[i])]
            else:
                legend_elements += [Patch(facecolor='k', edgecolor='k',
                                         label=colList[i])]
else:
        if len(colList)!=9:
            legend_elements += [Patch(facecolor=__clist[0], edgecolor=__clist[0],
                                     label=colList[0])]
        else:
            legend_elements += [Patch(facecolor='k', edgecolor='k',
                                     label=colList)]

plt.legend(handles=legend_elements,  bbox_to_anchor=(1.05, 0.9), loc='upper left')
plt.title("$\mu_{34}$ upregulates ROS species",fontsize=fs+5)
plt.xlabel('$\lambda_{\mu_{34}->noxROS}$',fontsize=fs+5)
plt.ylabel('$\lambda_{\mu_{34}->mtROS}$',fontsize=fs+5)
plt.tick_params(labelsize=fs)
plt.text(0.45, 0.6, 'Key: Accessible states', fontsize=fs)
plt.text(0.01, 0.55, 'Increasing upregulation', bbox=dict(boxstyle="larrow", fc="gray", ec="k", lw=1,alpha=0.6),fontsize=fs,rotation=90)
plt.text(0.15, -0.25, 'Increasing upregulation', bbox=dict(boxstyle="larrow", fc="gray", ec="k", lw=1,alpha=0.6),fontsize=fs)
fig.savefig("doubleCL_pres.png",bbox_inches='tight')
